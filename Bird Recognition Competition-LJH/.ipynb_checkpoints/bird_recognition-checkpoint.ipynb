# %%
import torch
from torch.autograd import Variable
import torch.nn as nn

import torchvision
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import torchvision.models as models

import math

import os
import numpy as np
import pandas as pd
from tqdm import tqdm

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
train_dir = '/Users/j/Documents/AI2/Bird Recognition Competition/train'
test_dir = '/Users/j/Documents/AI2/Bird Recognition Competition/val_and_test'
checkpoint_dir = '/Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints'
result_path = '/Users/j/Documents/AI2/Bird Recognition Competition/submission.csv'

# %%
# The "datasets" below open your images and preprocess them
#!!!!!!!!!!!!!!!!!!!!!!!!!!!! Why normalizing !!!!!!!!!!!!!!!!!!!!!!!!!!!!#
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

train_dataset = datasets.ImageFolder(
    train_dir,
    transforms.Compose([
        #!!!!!!!!!!!!!!!!!!!!!!!!!!!! What are these !!!!!!!!!!!!!!!!!!!!!!!!!!!!#
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.ToTensor(),
        normalize,
    ]))

test_dataset = datasets.ImageFolder(
    test_dir,
    transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ]))

image_array = np.array(train_dataset.imgs)
print(image_array.shape)

plt.imshow(mpimg.imread(train_dataset.imgs[0][0]))
# Out:
# (200, 2)

# %%
# The data loaders below collect your images and put them into batches to feed the neural network 
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=20, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=4)

# %%
# Define a simple CNN architecture
class Simple_CNN(nn.Module):
    def __init__(self, num_classes=2):
        super(Simple_CNN, self).__init__()
        self.features = nn.Sequential(
#             224->55 55->27
            nn.Conv2d(3, 8, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
#             27->23 23->11
            nn.Conv2d(8, 8, kernel_size=3, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
#             11->11 11->5
            nn.Conv2d(8, 16, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
#             5->5
            nn.Conv2d(16, 16, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
        )
#         5->1
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        self.classifier = nn.Sequential(
            nn.Linear(16, 16),
            nn.ReLU(inplace=True),
            nn.Linear(16, 16),
            nn.ReLU(inplace=True),
            nn.Linear(16, num_classes),
        )
    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

# %%
# Define VGG
class VGG(nn.Module):

    def __init__(self, features, num_classes=2):
        super(VGG, self).__init__()
        self.features = features
        self.classifier = nn.Sequential(
            nn.Linear(128 * 7 * 7, 512),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(512, 512),
            nn.ReLU(True),
            nn.Dropout(),
            nn.Linear(512, num_classes),
        )
        self._initialize_weights()

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

def make_layers(cfg, batch_norm=False):
    layers = []
    in_channels = 3
    for v in cfg:
        if v == 'M':
            layers += [nn.MaxPool2d(kernel_size=2, stride=2)]
        else:
            conv2d = nn.Conv2d(in_channels, v, kernel_size=3, padding=1)
            if batch_norm:
                layers += [conv2d, nn.BatchNorm2d(v), nn.ReLU(inplace=True)]
            else:
                layers += [conv2d, nn.ReLU(inplace=True)]
            in_channels = v
    return nn.Sequential(*layers)

cfg = {
    'A': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'B': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'D': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'E': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
    'L': [32, 'M', 32, 'M', 64, 64, 'M', 128, 128, 'M', 128, 128, 'M'],
}

def vgg11(**kwargs):
    """
    VGG 11-layer model (configuration "A")
    """
    model = VGG(make_layers(cfg['A']), **kwargs)
    return model

def vgg13(**kwargs):
    """
    VGG 13-layer model (configuration "B")
    """
    model = VGG(make_layers(cfg['B']), **kwargs)
    return model

def vgg16(**kwargs):
    """
    VGG 16-layer model (configuration "D")
    """
    model = VGG(make_layers(cfg['D']), **kwargs)
    return model

def vgg19(**kwargs):
    """
    VGG 19-layer model (configuration "E")
    """
    model = VGG(make_layers(cfg['E']), **kwargs)
    return model

def vggl(**kwargs):
    """
    VGGL 11-layer model (configuration "E")
    """
    model = VGG(make_layers(cfg['L']), **kwargs)
    return model

# %%
# Create a simple CNN
model = Simple_CNN()

# Create a ADAM optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Use cross-entropy loss
criterion = nn.CrossEntropyLoss()

# %%
# Create a VGGL CNN
# model = vggl()

# Create a ADAM optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Use cross-entropy loss
criterion = nn.CrossEntropyLoss()

# %%
def get_accuracy(output, target):
    """Computes the precision@k for the specified values of k"""
    batch_size = target.size(0)

    _, pred = output.topk(1, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))
    correct_k = correct[0].view(-1).float().sum(0, keepdim=True)

    return correct_k.mul_(1.0 / batch_size).data[0]

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def train(model, data_loader, criterion, optimizer):
    loss_recorder = AverageMeter() # record the loss of each batch to get the overall loss
    accuracy_recorder = AverageMeter() # record the accuracy of each batch to get the overall accuracy
    
    #!!!!!!!!!!!!!!!!!!!!!!!!!!!! What is this !!!!!!!!!!!!!!!!!!!!!!!!!!!!#
    model.train() # switch to train mode
    for i, (input, target) in enumerate(data_loader):
        input, target = Variable(input), Variable(target)
        output = model(input)
        loss = criterion(output, target)
        
        optimizer.zero_grad() # clear the gradients computed before
        loss.backward() # compute the gradients using backward propagation
        optimizer.step() # update the parameters of the network
        
        accuracy = get_accuracy(output, target)
        loss = loss.cpu().data[0] # convert from pytorch variable to a python float number
        print('Batch {}:\tloss: {:.05f}\t accuracy: {:.05f}'.format(i+1, loss, accuracy))
        loss_recorder.update(loss, input.size(0))
        accuracy_recorder.update(accuracy, input.size(0))
    return loss_recorder.avg, accuracy_recorder.avg

# %%
def validate(model, data_loader, criterion):
    loss_recorder = AverageMeter() # record the loss of each batch to get the overall loss
    accuracy_recorder = AverageMeter() # record the accuracy of each batch to get the overall accuracy
    model.eval() # switch to evaluation mode
    for i, (input, target) in enumerate(data_loader):
        input, target = Variable(input, volatile=True), Variable(target)
        output = model(input)
        loss = criterion(output, target)
        
        accuracy = get_accuracy(output, target)
        loss = loss.cpu().data[0] # convert from pytorch variable to a python float number
        print('Batch {}:\tloss: {:.05f}\t accuracy: {:.05f}'.format(i+1, loss, accuracy))
        loss_recorder.update(loss, input.size(0))
        accuracy_recorder.update(accuracy, input.size(0))
    return loss_recorder.avg, accuracy_recorder.avg

# %%
#!!!!!!!!!!!!!!!!!!!!!!!!!!!! Why Using Checkpoint !!!!!!!!!!!!!!!!!!!!!!!!!!!!#
def save_checkpoint(state, filename):
    torch.save(state, filename)
    print('A checkpoint was saved to {}'.format(filename))

# %%
num_epochs = 50

train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

for epoch in range(num_epochs):
    print('\nEpoch', epoch)
    
    print('---- train ----')
    train_loss, train_accuracy = train(model, train_loader, criterion, optimizer)
    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
        
    save_checkpoint(model.state_dict(), checkpoint_dir+'/checkpoint_epoch{}.pk'.format(epoch))
# Out:
# Epoch 0
# ---- train ----
# Batch 1:	loss: 0.65879	 accuracy: 0.65000
# Batch 2:	loss: 0.72137	 accuracy: 0.45000
# Batch 3:	loss: 0.68962	 accuracy: 0.55000
# Batch 4:	loss: 0.70520	 accuracy: 0.50000
# Batch 5:	loss: 0.70507	 accuracy: 0.50000
# Batch 6:	loss: 0.70458	 accuracy: 0.50000
# Batch 7:	loss: 0.68919	 accuracy: 0.55000
# Batch 8:	loss: 0.71877	 accuracy: 0.45000
# Batch 9:	loss: 0.76184	 accuracy: 0.30000
# Batch 10:	loss: 0.68893	 accuracy: 0.55000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch0.pk
#
# Epoch 1
# ---- train ----
# Batch 1:	loss: 0.70288	 accuracy: 0.50000
# Batch 2:	loss: 0.75725	 accuracy: 0.30000
# Batch 3:	loss: 0.70187	 accuracy: 0.50000
# Batch 4:	loss: 0.67537	 accuracy: 0.60000
# Batch 5:	loss: 0.71424	 accuracy: 0.45000
# Batch 6:	loss: 0.72630	 accuracy: 0.40000
# Batch 7:	loss: 0.67609	 accuracy: 0.60000
# Batch 8:	loss: 0.68828	 accuracy: 0.55000
# Batch 9:	loss: 0.68846	 accuracy: 0.55000
# Batch 10:	loss: 0.68814	 accuracy: 0.55000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch1.pk
#
# Epoch 2
# ---- train ----
# Batch 1:	loss: 0.69966	 accuracy: 0.50000
# Batch 2:	loss: 0.73326	 accuracy: 0.35000
# Batch 3:	loss: 0.66578	 accuracy: 0.65000
# Batch 4:	loss: 0.70955	 accuracy: 0.45000
# Batch 5:	loss: 0.67641	 accuracy: 0.60000
# Batch 6:	loss: 0.70949	 accuracy: 0.45000
# Batch 7:	loss: 0.66704	 accuracy: 0.65000
# Batch 8:	loss: 0.69895	 accuracy: 0.50000
# Batch 9:	loss: 0.73910	 accuracy: 0.30000
# Batch 10:	loss: 0.68695	 accuracy: 0.55000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch2.pk
#
# Epoch 3
# ---- train ----
# Batch 1:	loss: 0.69763	 accuracy: 0.50000
# Batch 2:	loss: 0.69584	 accuracy: 0.50000
# Batch 3:	loss: 0.65516	 accuracy: 0.70000
# Batch 4:	loss: 0.68470	 accuracy: 0.55000
# Batch 5:	loss: 0.69800	 accuracy: 0.50000
# Batch 6:	loss: 0.72019	 accuracy: 0.40000
# Batch 7:	loss: 0.68382	 accuracy: 0.55000
# Batch 8:	loss: 0.73164	 accuracy: 0.35000
# Batch 9:	loss: 0.69576	 accuracy: 0.50000
# Batch 10:	loss: 0.70789	 accuracy: 0.45000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch3.pk
#
# Epoch 4
# ---- train ----
# Batch 1:	loss: 0.68182	 accuracy: 0.55000
# Batch 2:	loss: 0.69736	 accuracy: 0.50000
# Batch 3:	loss: 0.64558	 accuracy: 0.75000
# Batch 4:	loss: 0.69922	 accuracy: 0.45000
# Batch 5:	loss: 0.71300	 accuracy: 0.40000
# Batch 6:	loss: 0.69439	 accuracy: 0.50000
# Batch 7:	loss: 0.71162	 accuracy: 0.40000
# Batch 8:	loss: 0.72409	 accuracy: 0.35000
# Batch 9:	loss: 0.67153	 accuracy: 0.60000
# Batch 10:	loss: 0.69104	 accuracy: 0.50000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch4.pk
#
# Epoch 5
# ---- train ----
# Batch 1:	loss: 0.69844	 accuracy: 0.45000
# Batch 2:	loss: 0.72213	 accuracy: 0.35000
# Batch 3:	loss: 0.69619	 accuracy: 0.45000
# Batch 4:	loss: 0.68413	 accuracy: 0.50000
# Batch 5:	loss: 0.68247	 accuracy: 0.55000
# Batch 6:	loss: 0.69833	 accuracy: 0.40000
# Batch 7:	loss: 0.69720	 accuracy: 0.40000
# Batch 8:	loss: 0.66656	 accuracy: 0.70000
# Batch 9:	loss: 0.67941	 accuracy: 0.55000
# Batch 10:	loss: 0.65959	 accuracy: 0.65000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch5.pk
#
# Epoch 6
# ---- train ----
# Batch 1:	loss: 0.72631	 accuracy: 0.35000
# Batch 2:	loss: 0.68792	 accuracy: 0.50000
# Batch 3:	loss: 0.70483	 accuracy: 0.55000
# Batch 4:	loss: 0.64961	 accuracy: 0.55000
# Batch 5:	loss: 0.69129	 accuracy: 0.45000
# Batch 6:	loss: 0.69501	 accuracy: 0.45000
# Batch 7:	loss: 0.63701	 accuracy: 0.60000
# Batch 8:	loss: 0.68292	 accuracy: 0.40000
# Batch 9:	loss: 0.62883	 accuracy: 0.65000
# Batch 10:	loss: 0.66364	 accuracy: 0.50000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch6.pk
#
# Epoch 7
# ---- train ----
# Batch 1:	loss: 0.69082	 accuracy: 0.60000
# Batch 2:	loss: 0.65676	 accuracy: 0.60000
# Batch 3:	loss: 0.67836	 accuracy: 0.45000
# Batch 4:	loss: 0.60932	 accuracy: 0.60000
# Batch 5:	loss: 0.63836	 accuracy: 0.60000
# Batch 6:	loss: 0.69679	 accuracy: 0.40000
# Batch 7:	loss: 0.76440	 accuracy: 0.30000
# Batch 8:	loss: 0.63021	 accuracy: 0.60000
# Batch 9:	loss: 0.64737	 accuracy: 0.45000
# Batch 10:	loss: 0.66020	 accuracy: 0.80000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch7.pk
#
# Epoch 8
# ---- train ----
# Batch 1:	loss: 0.68623	 accuracy: 0.70000
# Batch 2:	loss: 0.64744	 accuracy: 0.75000
# Batch 3:	loss: 0.66487	 accuracy: 0.60000
# Batch 4:	loss: 0.67651	 accuracy: 0.70000
# Batch 5:	loss: 0.62431	 accuracy: 0.75000
# Batch 6:	loss: 0.63263	 accuracy: 0.70000
# Batch 7:	loss: 0.63176	 accuracy: 0.80000
# Batch 8:	loss: 0.69673	 accuracy: 0.75000
# Batch 9:	loss: 0.65911	 accuracy: 0.65000
# Batch 10:	loss: 0.57349	 accuracy: 0.75000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch8.pk
#
# Epoch 9
# ---- train ----
# Batch 1:	loss: 0.64740	 accuracy: 0.80000
# Batch 2:	loss: 0.60274	 accuracy: 0.80000
# Batch 3:	loss: 0.49536	 accuracy: 0.90000
# Batch 4:	loss: 0.67098	 accuracy: 0.70000
# Batch 5:	loss: 0.62041	 accuracy: 0.65000
# Batch 6:	loss: 0.66288	 accuracy: 0.60000
# Batch 7:	loss: 0.67918	 accuracy: 0.60000
# Batch 8:	loss: 0.63478	 accuracy: 0.60000
# Batch 9:	loss: 0.66176	 accuracy: 0.65000
# Batch 10:	loss: 0.65711	 accuracy: 0.70000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epo

# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch42.pk
#
# Epoch 43
# ---- train ----
# Batch 1:	loss: 0.18569	 accuracy: 0.95000
# Batch 2:	loss: 0.30571	 accuracy: 0.90000
# Batch 3:	loss: 0.29697	 accuracy: 0.90000
# Batch 4:	loss: 0.22657	 accuracy: 0.90000
# Batch 5:	loss: 0.22589	 accuracy: 0.95000
# Batch 6:	loss: 0.42568	 accuracy: 0.80000
# Batch 7:	loss: 0.23118	 accuracy: 0.85000
# Batch 8:	loss: 0.23173	 accuracy: 0.85000
# Batch 9:	loss: 0.45472	 accuracy: 0.75000
# Batch 10:	loss: 0.36286	 accuracy: 0.90000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch43.pk
#
# Epoch 44
# ---- train ----
# Batch 1:	loss: 0.19958	 accuracy: 0.95000
# Batch 2:	loss: 0.09497	 accuracy: 1.00000
# Batch 3:	loss: 0.43491	 accuracy: 0.80000
# Batch 4:	loss: 0.37096	 accuracy: 0.80000
# Batch 5:	loss: 0.19682	 accuracy: 0.95000
# Batch 6:	loss: 0.16134	 accuracy: 0.95000
# Batch 7:	loss: 0.28353	 accuracy: 0.95000
# Batch 8:	loss: 0.24836	 accuracy: 0.90000
# Batch 9:	loss: 0.39010	 accuracy: 0.85000
# Batch 10:	loss: 0.57102	 accuracy: 0.80000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch44.pk
#
# Epoch 45
# ---- train ----
# Batch 1:	loss: 0.25399	 accuracy: 0.85000
# Batch 2:	loss: 0.44100	 accuracy: 0.80000
# Batch 3:	loss: 0.32898	 accuracy: 0.80000
# Batch 4:	loss: 0.30978	 accuracy: 0.90000
# Batch 5:	loss: 0.19945	 accuracy: 0.90000
# Batch 6:	loss: 0.28800	 accuracy: 0.90000
# Batch 7:	loss: 0.30010	 accuracy: 0.90000
# Batch 8:	loss: 0.53115	 accuracy: 0.80000
# Batch 9:	loss: 0.44127	 accuracy: 0.75000
# Batch 10:	loss: 0.24525	 accuracy: 0.90000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch45.pk
#
# Epoch 46
# ---- train ----
# Batch 1:	loss: 0.41364	 accuracy: 0.80000
# Batch 2:	loss: 0.24987	 accuracy: 0.90000
# Batch 3:	loss: 0.30208	 accuracy: 0.95000
# Batch 4:	loss: 0.21051	 accuracy: 0.90000
# Batch 5:	loss: 0.30455	 accuracy: 0.85000
# Batch 6:	loss: 0.18596	 accuracy: 0.95000
# Batch 7:	loss: 0.40298	 accuracy: 0.90000
# Batch 8:	loss: 0.32027	 accuracy: 0.80000
# Batch 9:	loss: 0.34525	 accuracy: 0.80000
# Batch 10:	loss: 0.32217	 accuracy: 0.80000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch46.pk
#
# Epoch 47
# ---- train ----
# Batch 1:	loss: 0.29892	 accuracy: 0.85000
# Batch 2:	loss: 0.11879	 accuracy: 1.00000
# Batch 3:	loss: 0.34306	 accuracy: 0.85000
# Batch 4:	loss: 0.29977	 accuracy: 0.85000
# Batch 5:	loss: 0.29337	 accuracy: 0.85000
# Batch 6:	loss: 0.28572	 accuracy: 0.80000
# Batch 7:	loss: 0.39882	 accuracy: 0.85000
# Batch 8:	loss: 0.30154	 accuracy: 0.85000
# Batch 9:	loss: 0.22452	 accuracy: 0.95000
# Batch 10:	loss: 0.29880	 accuracy: 0.90000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch47.pk
#
# Epoch 48
# ---- train ----
# Batch 1:	loss: 0.31207	 accuracy: 0.85000
# Batch 2:	loss: 0.39138	 accuracy: 0.80000
# Batch 3:	loss: 0.28974	 accuracy: 0.85000
# Batch 4:	loss: 0.09266	 accuracy: 1.00000
# Batch 5:	loss: 0.25560	 accuracy: 0.95000
# Batch 6:	loss: 0.28461	 accuracy: 0.90000
# Batch 7:	loss: 0.28688	 accuracy: 0.90000
# Batch 8:	loss: 0.30771	 accuracy: 0.85000
# Batch 9:	loss: 0.24818	 accuracy: 0.90000
# Batch 10:	loss: 0.11954	 accuracy: 1.00000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch48.pk
#
# Epoch 49
# ---- train ----
# Batch 1:	loss: 0.18973	 accuracy: 0.95000
# Batch 2:	loss: 0.14875	 accuracy: 1.00000
# Batch 3:	loss: 0.24319	 accuracy: 0.90000
# Batch 4:	loss: 0.19072	 accuracy: 0.90000
# Batch 5:	loss: 0.22521	 accuracy: 0.90000
# Batch 6:	loss: 0.37152	 accuracy: 0.80000
# Batch 7:	loss: 0.40255	 accuracy: 0.80000
# Batch 8:	loss: 0.27045	 accuracy: 0.95000
# Batch 9:	loss: 0.27951	 accuracy: 0.90000
# Batch 10:	loss: 0.26612	 accuracy: 0.95000
# A checkpoint was saved to /Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch49.pk

# %%
plt.figure()
plt.plot(np.arange(num_epochs)+1, train_losses)
#plt.plot(np.arange(num_epochs)+1, val_losses)
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])

# %%
plt.figure()
plt.plot(np.arange(num_epochs)+1, train_accuracies)
#plt.plot(np.arange(num_epochs)+1, val_accuracies)
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'val'])

# %% [markdown]
# Choose a model that you like best

# %%
prefered_checkpoint = '/Users/j/Documents/AI2/Bird Recognition Competition/.ipynb_checkpoints/checkpoint_epoch49.pk'
model.load_state_dict(torch.load(prefered_checkpoint))

# %% [markdown]
# Let your AI automatically recognize if there are birds in each images in test set

# %%
images = []
preds = []
model.eval()
for i, (input, target) in enumerate(tqdm(test_loader)):
    input, target = Variable(input, volatile=True), Variable(target)
    output = model(input)
    confidence = nn.functional.softmax(output, dim=1)
    confidence = confidence.cpu().data[0].numpy()
    if confidence[0] >= 0.5: # If the network predicts that the image contains a bird
        pred = 1
    else:
        pred = 0
    preds.append(pred)
    
    # Get the file name of the current image
    image = test_dataset.imgs[i]
    image = os.path.basename(image[0])
    images.append(image)
submission = pd.DataFrame({'image': images, 'has_bird': preds}, columns=['image', 'has_bird'])
# Out:
# 100%|██████████| 200/200 [00:00<00:00, 231.68it/s]

# %% [markdown]
# Take a look at the first rows of the result.

# %%
submission.head()
# Out:
#       image  has_bird
# 0  0000.JPG         1
# 1  0001.JPG         0
# 2  0002.JPG         1
# 3  0003.JPG         1
# 4  0004.JPG         0

# %%
submission.to_csv(result_path, index=False)
